# %% [markdown]
# <a href="https://colab.research.google.com/github/dmitrikru/sech/blob/main/_untitled1_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("это моё первое кодовое поле")
# Out:
# это моё первое кодовое поле

# %% [markdown]
# Это моё первое текстовое поле.

# %% [markdown]
# Тестовый блокнот в Colab
