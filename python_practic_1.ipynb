# %% [markdown]
# <a href="https://colab.research.google.com/github/dmitrikru/sech/blob/colab-notebooks/python_practic_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Практика №1 - решение задач**

# %%
print ('Hello World')
# Out:
# Hello World

# %%
print(4,8,15,16,23,42)
# Out:
# 4 8 15 16 23 42

# %%
c="*"
print(c)
print(c*2)
print(c*3)
print(c*4)
print(c*5)
print(c*6)
print(c*7)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******

# %%
print(" Отчёт о доходах\n 1 квартал 120000 руб.\n 2 квартал 135000 руб.\n 3 квартал 128000 руб.\n 4 квартал 142000 руб.")
# Out:
#  Отчёт о доходах
#  1 квартал 120000 руб.
#  2 квартал 135000 руб.
#  3 квартал 128000 руб.
#  4 квартал 142000 руб.

# %%
analityc_name = input()
print('Добро пожаловать в команду,', analityc_name, '!')
# Out:
# Влад
# Добро пожаловать в команду, Влад !

# %%
name_company = input()
print(name_company, "- лидер рынка!")
# Out:
# Сбер
# Сбер - лидер рынка!

# %%
name = ('Sales Q1')
dig_strok = ('1000')
dig_columns = ('8')
print(name,'\n',dig_strok,'\n',dig_columns)
# Out:
# Sales Q1
#  1000
#  8

# %%
otchet1 = ('Продажи за январь')
otchet2 = ('Продажи за февраль')
otchet3 = ('Продажи за март')

print(otchet3)
print(otchet2)
print(otchet1)
# Out:
# Продажи за март
# Продажи за февраль
# Продажи за январь

# %%
base_price = 100
growth_persent = 20
new_price = base_price * (100 + growth_persent)/100
delta = (new_price - base_price)
print ('new_price =', new_price, '\n', 'delta =', delta)
# Out:
# new_price = 120.0
#  delta = 20.0

# %%
input1 = input()
input2 = input()
input3 = input()
input4 = input1 + '***' + input2 + '***' + input3
print(input4)
# Out:
# Северный
# Центральный
# Южный
# Северный***Центральный***Южный

# %%
region1 = 'Северный'
region2 = 'Центральный'
region3 = 'Южный'
print (region1, region2, region3, sep='***')
# Out:
# Северный***Центральный***Южный

# %%
name = input()
print("Подключение установлено.", end=' ')
print ('Добро пожаловать', name)
# Out:
# Влад
# Подключение установлено. Добро пожаловать Влад

# %%
a=input("Разделитель:")
b=input("Название товара 1: ")
c=input("Название товара 2: ")
d=input("Название товара 3: ")
print(b,c,d,sep=' '+a+' ')
# Out:
# Разделитель:|
# Название товара 1: Молоко
# Название товара 2: Хлеб
# Название товара 3: Сыр
# Молоко | Хлеб | Сыр

# %%
value_str = "42.7"
value_float = float(value_str)
print (value_float)
integer_part = int(value_float)
print("integer_part = ", integer_part)
# Out:
# 42.7
# integer_part =  42

# %%
orders_yesterday = 10
plan = 20
deviation = abs(plan - orders_yesterday)
print('Абсолютное отклонение от плана равняется ', deviation)
# Out:
# Абсолютное отклонение от плана равняется  10

# %%
dig1=1
dig2=2
dig3=3
dig4=4
dig5=5
max_dig = max (dig1, dig2, dig3, dig4, dig5)
min_dig = min (dig1, dig2, dig3, dig4, dig5)
print ('Наибольшее число =', max_dig)
print ("Наименьшее число =", min_dig)
# Out:
# Наибольшее число = 5
# Наименьшее число = 1

# %%
name = 'Антон'
family_name = 'Иванов'
full_name = name + " " + family_name
print('Привет,', full_name,'! Вы только что начали изучать Python')
# Out:
# Привет, Антон Иванов ! Вы только что начали изучать Python

# %%
input1 = input()
input2 = input()
input3 = '"' + input1 + input2 +'"'
print(input3)
# Out:
# Каждый в этой стране должен научиться программировать,
# потому что это учит думать
# "Каждый в этой стране должен научиться программировать, потому что это учит думать"

# %%
actual = int(input())
plan = int(input())
print('Скидка предоставляется:', actual >= plan)
# Out:
# 999
# 1000
# Скидка предоставляется: False

# %%
actual = int(input())
plan = 18
print('Юзер вырос:', actual >= plan)
# Out:
# 16
# Юзер вырос: False

# %%
s = int(500)
v1 = int(50)
v2 = int(70)
t = s / (v1 + v2)
print(t)
# Out:
# 4.166666666666667

# %%
catet_a = int(443)
catet_b = int(390)
s = (catet_a * catet_b)/2
print (s)
# Out:
# 86385.0

# %%
tf = float(450.55)
tc = (5/9 * (tf-32))
print (tc)
# Out:
# 232.5277777777778

# %%
revenue_str = (438746.78)
courier_name = ('Антон')
bonus = (1)
full_bonus = (revenue_str * bonus) / 100
bonus_int = int(full_bonus)
print ('report = "Курьер', courier_name, 'получит бонус', bonus_int , 'р."')
# Out:
# report = "Курьер Антон получит бонус 4387 р."
